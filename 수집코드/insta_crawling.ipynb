# %%
import pandas as pd
import sys
from selenium import webdriver as wd
import time
import random
import urllib.request
import re
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys

# %%
driver = wd.Chrome('C://Users//USER//Desktop//Py_Projects//selenium_level4//chromedriver')
driver.get("https://www.instagram.com/accounts/login/?__coig_restricted=1")

time.sleep(1)

# %%
# 아이디
id = "개인정보"
# 비밀번호
pw = "개인정보"

input = driver.find_elements_by_tag_name("input")

input[0].send_keys(id)

# 비밀번호 입력
input[1].send_keys(pw)

# 엔터
input[1].send_keys(Keys.RETURN)
time.sleep(5)

# %%
# 로그인 정보 저장 여부 ("나중에 하기 버튼 클릭")
btn_later1 = driver.find_element_by_class_name('_acan._acao._acas')
btn_later1.click()
time.sleep(3)

# 알림 설정 ("나중에 하기 버튼 클릭")
btn_later2 = driver.find_element_by_class_name('_a9--._a9_1')
btn_later2.click()
time.sleep(2)

# %%
# 함수 정의: 검색어 조건에 따른 url 생성 -> 이동
keyword = word = urllib.parse.quote("최저임금")
url = f'https://www.instagram.com/explore/tags/{keyword}/'
driver.get(url)
time.sleep(3)

# %%
# 스크롤 내리기
num = random.randrange(0, 30)
for n in range(30):
    print(n)
    driver.execute_script('''
        // 자바스크립트 작성
        window.scrollBy(0, 2000)
    ''')
    time.sleep(num)

# %%
# 첫번쨰 게시물 클릭
for f_instar in driver.find_elements_by_css_selector("div._aagw"):
    print( f_instar )
    f_instar.click()
    break

# %%
# 전체 
my_dict = []

while True:
    try : 
        #  댓글 개수
        text_count = len(driver.find_elements_by_css_selector('._a9zs'))

        # 본문+날짜+좋아요를 딕셔너리로 생성
        content = driver.find_elements_by_css_selector('._a9zs')
        title = driver.find_elements_by_css_selector('a > ._a9ze._a9zf')
        tag = driver.find_elements_by_css_selector('._aacl._aacn._aacw._aacy._aad6._aade')
        

        # # 더보기 버튼 클릭
        num = random.randrange(1, 10)
        while True:
            time.sleep(num)
            try :
                comment_move = driver.find_elements_by_css_selector("#mount_0_0_hg > div > div > div > div:nth-child(4) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div.xb88tzc.xw2csxc.x1odjw0f.x5fp0pe.x1qjc9v5.xjbqb8w.x1lcm9me.x1yr5g0i.xrt01vj.x10y3i5r.x47corl.xh8yej3.x15h9jz8.xr1yuqi.xkrivgy.x4ii5y1.x1gryazu.xir0mxb.x1juhsu6 > div > article > div > div._ae65 > div > div > div._ae2s._ae3v._ae3w > div._ae5q._ae5r._ae5s > ul > li > div > button")[0]   
                comment_move.click()
                time.sleep(num)
            except: break

        # 게시물 내용 수집
        try:
            main_text = {   
                            '댓글내용' : content[0].text,
                            '날짜' : title[0].get_attribute('title'),
                            '좋아요' : driver.find_element_by_css_selector('div._aacl._aaco._aacw._aacx._aada._aade span').text
                        }
            my_dict.append(main_text)
            print(main_text)
        except Exception as e: print(str(e))
        
        # 댓글 내용 수집
        t = 0
        for i in range(1, len(content)):
            tag_text = tag[t].text
            if '답글 달기' in tag_text:
                t += 1
                tag_text = '0'
            else:
                tag_text = tag_text.replace('좋아요 ','').replace("개", '')
                t += 2

            tag_like_dict = {
                '댓글내용' : content[i].text,
                '날짜' : title[i].get_attribute('title'),
                '좋아요' : tag_text
            }
            my_dict.append(tag_like_dict)
            print(tag_like_dict)
    except Exception as e: print(str(e))

    # 다음 게시물 클릭
    try : 
        next_move = driver.find_elements_by_css_selector("._aaqg._aaqh")[0]    
        next_move.click()
        time.sleep(2 + num*0.5)
    except: break

# %%
# 게시물 하나하나 직접할 때
my_dict = []    # 한번만 클릭

# %%
# 자동으로 더보기 버튼 계속 누르는 코드
num = random.randrange(1, 10)
while True:
    time.sleep(num*0.3)
    try :
        comment_move = driver.find_elements_by_css_selector("#mount_0_0_hg > div > div > div > div:nth-child(4) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div.xb88tzc.xw2csxc.x1odjw0f.x5fp0pe.x1qjc9v5.xjbqb8w.x1lcm9me.x1yr5g0i.xrt01vj.x10y3i5r.x47corl.xh8yej3.x15h9jz8.xr1yuqi.xkrivgy.x4ii5y1.x1gryazu.xir0mxb.x1juhsu6 > div > article > div > div._ae65 > div > div > div._ae2s._ae3v._ae3w > div._ae5q._ae5r._ae5s > ul > li > div > button")[0]   
        comment_move.click()
        time.sleep(num*0.3)
    except: break

# %%
# 게시물 하나 내에서 댓글 수집
try : 
    #  댓글 개수
    text_count = len(driver.find_elements_by_css_selector('._a9zs'))

    # 본문+날짜+좋아요를 딕셔너리로 생성
    content = driver.find_elements_by_css_selector('._a9zs')
    title = driver.find_elements_by_css_selector('a > ._a9ze._a9zf')
    tag = driver.find_elements_by_css_selector('._aacl._aacn._aacw._aacy._aad6._aade')
    

    # # 더보기 버튼 클릭
    # num = random.randrange(1, 5)
    # while True:
    #     time.sleep(num)
    #     try :
    #         comment_move = driver.find_elements_by_css_selector("#mount_0_0_hg > div > div > div > div:nth-child(4) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div.xb88tzc.xw2csxc.x1odjw0f.x5fp0pe.x1qjc9v5.xjbqb8w.x1lcm9me.x1yr5g0i.xrt01vj.x10y3i5r.x47corl.xh8yej3.x15h9jz8.xr1yuqi.xkrivgy.x4ii5y1.x1gryazu.xir0mxb.x1juhsu6 > div > article > div > div._ae65 > div > div > div._ae2s._ae3v._ae3w > div._ae5q._ae5r._ae5s > ul > li > div > button")[0]   
    #         comment_move.click()
    #         time.sleep(num)
    #     except: break

    # 게시물 내용 수집
    try:
        main_text = {   
                        '댓글내용' : content[0].text,
                        '날짜' : title[0].get_attribute('title'),
                        '좋아요' : driver.find_element_by_css_selector('div._aacl._aaco._aacw._aacx._aada._aade span').text
                    }
        my_dict.append(main_text)
        print(main_text)
    except Exception as e: print(str(e))
    
    # 댓글 내용 수집
    t = 0
    for i in range(1, len(content)):
        tag_text = tag[t].text
        if '답글 달기' in tag_text:
            t += 1
            tag_text = '0'
        else:
            tag_text = tag_text.replace('좋아요 ','').replace("개", '')
            t += 2

        tag_like_dict = {
            '댓글내용' : content[i].text,
            '날짜' : title[i].get_attribute('title'),
            '좋아요' : tag_text
        }
        my_dict.append(tag_like_dict)
        print(tag_like_dict)
except Exception as e: print(str(e))

# %%
# excel에 저장
df = pd.DataFrame.from_dict(my_dict)
df.to_excel('만나이_insta_infos.xlsx', index=False)
